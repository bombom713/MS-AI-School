# %% [markdown]
# # 인공신경망 가중치 적용한 시각화 실습

# %%
import torch
import matplotlib.pyplot as plt

# %%
# 2차원 가중치 행렬을 랜덤으로 초기화 
w = torch.randn(3,3)
print(w)

w_flattend = w.flatten()
print(w_flattend)
# Out:
# tensor([[-0.7271,  1.0458,  0.7218],
#         [-0.9639,  1.2394, -0.2518],
#         [ 2.4011, -0.3193,  0.3663]])
# tensor([-0.7271,  1.0458,  0.7218, -0.9639,  1.2394, -0.2518,  2.4011, -0.3193,
#          0.3663])

# %% [markdown]
# ### 시각화

# %%
plt.hist(w_flattend, bins=20)
plt.xlabel('Weight value')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# # 크기가 1인 랜덤한 값을 가지는 편향을 생성

# %%
b = torch.rand(1) # 편형을 랜덤으로 초기화 

print(b)
# 편형 값을 시각화 
plt.hist(b.detach().numpy(), bins=20) # b.detach().numpy() -> 텐서를 넘파이 배열로 변환 
plt.xlabel('Bias value')
plt.ylabel('Frequency')
plt.show()
# Out:
# tensor([0.1636])
